# %% [markdown]
# # 誤り率

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy.special import comb

# %%
n = 7
t = 1
p = 7e-4

P_E_max = sum(comb(n, i) * p ** i * (1 - p) ** (n - i) for i in range(t + 1, n + 1))
# for i in range(t + 1, n + 1):
#     P_E_max += comb(n, i) * p ** i * (1 - p) ** (n - i)
P_E_max
# Out:
# 1.0266015196386234e-05

# %%
# (7, 4)ハミング限定?
1 - (1 - p) ** 6 * (1 + 6 * p)
# Out:
# 1.0266015196602751e-05

# %%
N = 1000
x = np.logspace(-5, -1, N)
# print(x)
# y = 1 - (1 - x) ** 6 * (1 + 6 * x)
y = sum(comb(n, i) * x ** i * (1 - x) ** (n - i) for i in range(t + 1, n + 1))
# print(y)

# 比較対象. 4bit符号化なし
no_code = 1 - (1 - x) ** 4

fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111)
ax.plot(x, y)
# ax.plot(x, no_code)
ax.set_xscale("log")
ax.set_yscale("log")
ax.set_yticks(np.logspace(-9, -1, 9))
ax.set_xlabel("$p$", fontsize=15)
ax.set_ylabel("$P(E)$", fontsize=15)
ax.set_xlim([1e-5, 1e-1])
ax.set_ylim([1e-9, 1e0])
ax.grid(which="major", axis="y")
ax.grid(which="both", axis="x")
# ax.minorticks_on()

# %%
fig.savefig("figures/test.pdf", bbox_inches="tight")
