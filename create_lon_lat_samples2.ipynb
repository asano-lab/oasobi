# %%
import folium
import pandas as pd
import numpy as np
from folium.features import CustomIcon

# %%
f = folium.Figure()

center_lat, center_lon = 36.63145, 138.1881
# center_lat, center_lon = 80.0, -30.0

# 緯度1°あたりの距離(m)
dist_per_lat = 1852 * 60
dist_per_lon = dist_per_lat * np.cos(np.deg2rad(center_lat))
# print(dist_per_lat, dist_per_lon)

m = folium.Map([center_lat, center_lon], zoom_start=5).add_to(f)
folium.Marker(location=[center_lat, center_lon]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_48c999697e74798c1beb89db288c9fc3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_48c999697e74798c1beb89db288c9fc3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_48c999697e74798c1beb89db288c9fc3 = L.map(
#                 &quot;map_48c999697e74798c1beb89db288c9fc3&quot;,
#                 {
#                     center: [36.63145, 138.1881],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9885dea954f3bb889d1bb026ea5af537 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_48c999697e74798c1beb89db288c9fc3);
#
#
#             var marker_ec38baf0dc9c20e8ec87f9ae9bfc48f1 = L.marker(
#                 [36.63145, 138.1881],
#                 {}
#             ).addTo(map_48c999697e74798c1beb89db288c9fc3);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
N = 19
arr = np.arange(N)

radius = 50

circle_lat = radius / dist_per_lat * np.sin(arr / N * np.pi * 2) + center_lat
circle_lon = radius / dist_per_lon * np.cos(arr / N * np.pi * 2) + center_lon

circle_lat_lon = np.stack([circle_lat, circle_lon], axis=1)

pd.options.display.precision = 6

df = pd.DataFrame(circle_lat_lon, columns=["lat", "lon"])
df
# Out:
#           lat         lon
# 0   36.631450  138.188661
# 1   36.631596  138.188630
# 2   36.631726  138.188542
# 3   36.631827  138.188407
# 4   36.631886  138.188238
# 5   36.631898  138.188054
# 6   36.631862  138.187875
# 7   36.631781  138.187720
# 8   36.631664  138.187607
# 9   36.631524  138.187547
# 10  36.631376  138.187547
# 11  36.631236  138.187607
# 12  36.631119  138.187720
# 13  36.631038  138.187875
# 14  36.631002  138.188054
# 15  36.631014  138.188238
# 16  36.631073  138.188407
# 17  36.631174  138.188542
# 18  36.631304  138.188630

# %%
f = folium.Figure()

m = folium.Map([center_lat, center_lon], zoom_start=20).add_to(f)

icon_fname_format = "images/arrow%s.png"
icon_colors = ["91ee8f", "c8e147", "ffd300", "ff6900", "ff0000"]
icon_paths = [icon_fname_format % i for i in icon_colors]
print(icon_paths)
# icons = [CustomIcon(icon_image=i, icon_size=(10, 20)) for i in icon_paths]
# print(icons)

for i in arr:
    alert_level = i // 3
    if alert_level < 4:
        icon_path = icon_paths[alert_level]
    else:
        icon_path = icon_paths[4]
    icon = CustomIcon(icon_image=icon_path, icon_size=(10, 20), icon_anchor=(5, 20))
#     folium.Marker(location=[df["lat"][i], df["lon"][i]]).add_to(m)
    folium.Marker(location=[df["lat"][i], df["lon"][i]], icon=icon, tooltip=alert_level).add_to(m)
m
# Out:
# ['images/arrow91ee8f.png', 'images/arrowc8e147.png', 'images/arrowffd300.png', 'images/arrowff6900.png', 'images/arrowff0000.png']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c33ec2ff6d9e9a977cf5bd7671ce321a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c33ec2ff6d9e9a977cf5bd7671ce321a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c33ec2ff6d9e9a977cf5bd7671ce321a = L.map(
#                 &quot;map_c33ec2ff6d9e9a977cf5bd7671ce321a&quot;,
#                 {
#                     center: [36.63145, 138.1881],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 20,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a121f2fe7b74877b151671d6cfab2830 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c33ec2ff6d9e9a977cf5bd7671ce321a);
#
#
#             var marker_0f34b83ad8ed5f8681a5646af40f2eb6 = L.marker(
#                 [36.63145, 138.1886607097365],
#                 {}
#             ).addTo(map_c33ec2ff6d9e9a977cf5bd7671ce321a);
#
#
#         var custom_icon_ff547cdccadd8cdbf8e77179eb0945a0 = L.icon({&quot;iconAnchor&quot;: [5, 20], &quot;iconSize&quot;: [10, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_0f34b83ad8ed5f8681a5646af40f2eb6.setIcon(custom_icon_ff547cdccadd8cdbf8e77179eb0945a0);
#
#
#             marker_0f34b83ad8ed5f8681a5646af40f2eb6.bindTooltip(
#                 `&lt;div&gt;
#                      0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_c24d2ecccb173710c0941d0fec8951b5 = L.marker(
#                 [36.631596103072894, 138.18863032893637],
#                 {}
#             ).addTo(map_c33ec2ff6d9e9a977cf5bd7671ce321a);
#
#
#         var custom_icon_33ed57508e5a3a623006b7283b47ea0a = L.icon({&quot;iconAnchor&quot;: [5, 20], &quot;iconSize&quot;: [10, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_c24d2ecccb173710c0941d0fec8951b5.setIcon(custom_icon_33ed57508e5a3a623006b7283b47ea0a);
#
#
#             marker_c24d2ecccb173710c0941d0fec8951b5.bindTooltip(
#                 `&lt;div&gt;
#                      0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_83c4ec4530a4313dbde061b4e5a06385 = L.marker(
#                 [36.631726373610825, 138.18854247876706],
#                 {}
#             ).addTo(map_c33ec2ff6d9e9a977cf5bd7671ce321a);
#
#
#         var custom_icon_357b81c2bd0d4723ecfd647daafee86e = L.icon({&quot;iconAnchor&quot;: [5, 20], &quot;iconSize&quot;: [10, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_83c4ec4530a4313dbde061b4e5a06385.setIcon(custom_icon_357b81c2bd0d4723ecfd647daafee86e);
#
#
#             marker_83c4ec4530a4313dbde061b4e5a06385.bindTooltip(
#                 `&lt;div&gt;
#                      0
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_2235f1495ec11cd87b7e5c3cdd38253b = L.marker(
#                 [36.63182669477964, 138.1884066791576],
#                 {}
#             ).addTo(map_c33ec2ff6d9e9a977cf5bd7671ce321a);
#
#
#         var custom_icon_175748690f154d77b3b18ee46725c75f = L.icon({&quot;iconAnchor&quot;: [5, 20], &quot;iconSize&quot;: [10, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_2235f1495ec11cd87b7e5c3cdd38253b.setIcon(custom_icon_175748690f154d77b3b18ee46725c75f);
#
#
#             marker_2235f1495ec11cd87b7e5c3cdd38253b.bindTooltip(
#                 `&lt;div&gt;
#                      1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5216273f440b60f414dbadcd16085a54 = L.marker(
#                 [36.631886195224055, 138.1882376461028],
#                 {}
#             ).addTo(map_c33ec2ff6d9e9a977cf5bd7671ce321a);
#
#
#         var custom_icon_b02398e678ce3a47b68af618fb47fa34 = L.icon({&quot;iconAnchor&quot;: [5, 20], &quot;iconSize&quot;: [10, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_5216273f440b60f414dbadcd16085a54.setIcon(custom_icon_b02398e678ce3a47b68af618fb47fa34);
#
#
#             marker_5216273f440b60f414dbadcd16085a54.bindTooltip(
#                 `&lt;div&gt;
#                      1
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e341fb1f44934a78957911e4a23c2172 = L.marker(
#                 [36.63189842714768, 138.18805369695696],
#                 {}
#             ).addTo(map_c33ec2ff6d9e9a977cf5bd7671ce321a);
#
#
#         var custom_icon_ebc8a8a4fc970924ea972c6ed35b19ae = L.icon({&quot;iconAnchor&quot;: [5, 20], &quot;iconSize&quot;: [10, 20], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_e341fb1f44934a78957911e4a23c2172.setIcon(custom_icon_ebc8a8a4f

# %%
df.to_csv("csv/circle_sampe_n%d_lat%.4f.csv" % (N, center_lat), index=False)

# %%
df_vector = df[1:].copy()
df_vector["lat_prev"] = df[:-1]["lat"].tolist()
df_vector["lon_prev"] = df[:-1]["lon"].tolist()
df_vector["delta_lat"] = df_vector["lat"] - df_vector["lat_prev"]
df_vector["delta_lon"] = df_vector["lon"] - df_vector["lon_prev"]
df_vector["theta"] = np.arctan2(df_vector["delta_lat"], df_vector["delta_lon"])
df_vector
# Out:
#           lat         lon   lat_prev    lon_prev  delta_lat  delta_lon  \
# 1   36.631596  138.188630  36.631450  138.188661   0.000146  -0.000030
# 2   36.631726  138.188542  36.631596  138.188630   0.000130  -0.000088
# 3   36.631827  138.188407  36.631726  138.188542   0.000100  -0.000136
# 4   36.631886  138.188238  36.631827  138.188407   0.000060  -0.000169
# 5   36.631898  138.188054  36.631886  138.188238   0.000012  -0.000184
# 6   36.631862  138.187875  36.631898  138.188054  -0.000036  -0.000179
# 7   36.631781  138.187720  36.631862  138.187875  -0.000081  -0.000155
# 8   36.631664  138.187607  36.631781  138.187720  -0.000117  -0.000113
# 9   36.631524  138.187547  36.631664  138.187607  -0.000140  -0.000060
# 10  36.631376  138.187547  36.631524  138.187547  -0.000148   0.000000
# 11  36.631236  138.187607  36.631376  138.187547  -0.000140   0.000060
# 12  36.631119  138.187720  36.631236  138.187607  -0.000117   0.000113
# 13  36.631038  138.187875  36.631119  138.187720  -0.000081   0.000155
# 14  36.631002  138.188054  36.631038  138.187875  -0.000036   0.000179
# 15  36.631014  138.188238  36.631002  138.188054   0.000012   0.000184
# 16  36.631073  138.188407  36.631014  138.188238   0.000060   0.000169
# 17  36.631174  138.188542  36.631073  138.188407   0.000100   0.000136
# 18  36.631304  138.188630  36.631174  138.188542   0.000130   0.000088
#
#        theta
# 1   1.775816
# 2   2.164111
# 3   2.505334
# 4   2.803133
# 5   3.075194
# 6  -2.941105
# 7  -2.658700
# 8  -2.340913
# 9  -1.975031
# 10 -1.570796
# 11 -1.166562
# 12 -0.800679
# 13 -0.482893
# 14 -0.200488
# 15  0.066398
# 16  0.338460
# 17  0.636258
# 18  0.977482

# %%
def compute_theta_delta(x):
    x = abs(x)
    if (x > 180):
        x = 360 - x
    return x

# %%
df_direction = df_vector[1:][["theta"]].copy()
df_direction["theta_prev"] = df_vector["theta"][:-1].tolist()
df_direction["delta_theta"] = np.rad2deg(df_direction["theta"] - df_direction["theta_prev"]).apply(compute_theta_delta)
df_direction
# Out:
#        theta  theta_prev  delta_theta
# 2   2.164111    1.775816    22.247696
# 3   2.505334    2.164111    19.550649
# 4   2.803133    2.505334    17.062607
# 5   3.075194    2.803133    15.587960
# 6  -2.941105    3.075194    15.291466
# 7  -2.658700   -2.941105    16.180592
# 8  -2.340913   -2.658700    18.207847
# 9  -1.975031   -2.340913    20.963500
# 10 -1.570796   -1.975031    23.160948
# 11 -1.166562   -1.570796    23.160948
# 12 -0.800679   -1.166562    20.963500
# 13 -0.482893   -0.800679    18.207847
# 14 -0.200488   -0.482893    16.180592
# 15  0.066398   -0.200488    15.291466
# 16  0.338460    0.066398    15.587960
# 17  0.636258    0.338460    17.062607
# 18  0.977482    0.636258    19.550649

# %%
df_direction["delta_theta"].sum()
# Out:
# 314.2588318173549

# %%
def compute_arc_length(lat1, lat2, lon1, lon2):
    """
    緯度経度から距離を計算 (単位球)
    """
    return np.arccos(np.sin(lat1) * np.sin(lat2) + np.cos(lat1) * np.cos(lat2) * np.cos(lon2 - lon1))

# %%
df_3points = df[:-2].copy().rename(columns={"lat": "lat1", "lon": "lon1"})
df_3points["lat2"] = df[1:-1]["lat"].tolist()
df_3points["lon2"] = df[1:-1]["lon"].tolist()
df_3points["lat3"] = df[2:]["lat"].tolist()
df_3points["lon3"] = df[2:]["lon"].tolist()
df_3points = np.deg2rad(df_3points)
c = compute_arc_length(df_3points["lat1"], df_3points["lat2"], df_3points["lon1"], df_3points["lon2"])
b = compute_arc_length(df_3points["lat2"], df_3points["lat3"], df_3points["lon2"], df_3points["lon3"])
a = compute_arc_length(df_3points["lat3"], df_3points["lat1"], df_3points["lon3"], df_3points["lon1"])

df_3points["a"] = a
df_3points["b"] = b
df_3points["c"] = c

df_3points["alpha"] = np.arccos((np.cos(a) - np.cos(b) * np.cos(c)) / (np.sin(b) * np.sin(c)))

# 表示法の変更
pd.options.display.precision = 2

df_3points
# Out:
#     lat1  lon1  lat2  lon2  lat3  lon3         a         b         c  alpha
# 0   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 1   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 2   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 3   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 4   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 5   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 6   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 7   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 8   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 9   0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 10  0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 11  0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 12  0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 13  0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 14  0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 15  0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81
# 16  0.64  2.41  0.64  2.41  0.64  2.41  5.10e-06  2.59e-06  2.59e-06   2.81

# %%
df_3points["delta_theta"] = 180 - np.rad2deg(df_3points[["alpha"]])
df_3points[["delta_theta"]]
# Out:
#     delta_theta
# 0         18.95
# 1         18.95
# 2         18.94
# 3         18.94
# 4         18.95
# 5         18.95
# 6         18.94
# 7         18.94
# 8         18.95
# 9         18.95
# 10        18.96
# 11        18.95
# 12        18.94
# 13        18.94
# 14        18.95
# 15        18.94
# 16        18.94

# %%
df_3points["delta_theta"].sum()
# Out:
# 322.05996853652675

# %%
def fix_angle(x):
    x = abs(x)
    if (x > 180):
        x = 360 - x
    return x

# %%
lat1 = df_3points["lat1"]
lat2 = df_3points["lat2"]
lat3 = df_3points["lat3"]
lon1 = df_3points["lon1"]
lon2 = df_3points["lon2"]
lon3 = df_3points["lon3"]

theta1 = np.arctan2(lat2 - lat1, (lon2 - lon1) * np.cos((lat1 + lat2) / 2))
theta2 = np.arctan2(lat3 - lat2, (lon3 - lon2) * np.cos((lat2 + lat3) / 2))
delta_theta = theta2 - theta1
np.rad2deg(delta_theta).apply(fix_angle)
# Out:
# 0     18.95
# 1     18.95
# 2     18.95
# 3     18.95
# 4     18.95
# 5     18.95
# 6     18.95
# 7     18.95
# 8     18.95
# 9     18.95
# 10    18.95
# 11    18.95
# 12    18.95
# 13    18.95
# 14    18.95
# 15    18.95
# 16    18.95
# dtype: float64

# %%
tokyo_station = [35.681236, 139.767125]
tokyo_tower = [35.658581, 139.745433]
gri = [35.6597, 139.75195]

m = folium.Map(
    location=gri,
    tiles='OpenStreetMap',
    zoom_start=13
)

marker = folium.Marker(
    location=gri,
    popup='hogehoge',
    icon=folium.Icon(color='orange')
)

polyline = pd.DataFrame([tokyo_station, gri, tokyo_tower], columns=["lat", "lon"])

line = folium.vector_layers.PolyLine(
    locations=polyline,
    color="olive",                 
    weight=10
)

# マーカーと線の地図レイヤへの追加
m.add_child(marker)
m.add_child(line)

sample_dot = [35.67, 139.74]

icon = CustomIcon(
    icon_image = "images/maru00ff00.png",
    icon_size = (10, 10)
)

m.add_child(
    folium.Marker(
        location=sample_dot,
        tooltip="mouse over",
#         popup="sample",
#         icon=folium.Icon(color="blue"),
        icon=icon
    )
)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39e3c8a1d0e59601a84254736a69ae08 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39e3c8a1d0e59601a84254736a69ae08&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_39e3c8a1d0e59601a84254736a69ae08 = L.map(
#                 &quot;map_39e3c8a1d0e59601a84254736a69ae08&quot;,
#                 {
#                     center: [35.6597, 139.75195],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_438144af023e4a17a0fbbd149003e6a9 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39e3c8a1d0e59601a84254736a69ae08);
#
#
#             var marker_01ab4716a615a0d02d99bafe5044a5e4 = L.marker(
#                 [35.6597, 139.75195],
#                 {}
#             ).addTo(map_39e3c8a1d0e59601a84254736a69ae08);
#
#
#             var icon_fc544ed9d916c28bc684b222471a716c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;orange&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_01ab4716a615a0d02d99bafe5044a5e4.setIcon(icon_fc544ed9d916c28bc684b222471a716c);
#
#
#         var popup_a8c3922cfb7e8be63643ffb4dde3aa2f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f67a11b26414cc90215b18aca1577a52 = $(`&lt;div id=&quot;html_f67a11b26414cc90215b18aca1577a52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;hogehoge&lt;/div&gt;`)[0];
#             popup_a8c3922cfb7e8be63643ffb4dde3aa2f.setContent(html_f67a11b26414cc90215b18aca1577a52);
#
#
#         marker_01ab4716a615a0d02d99bafe5044a5e4.bindPopup(popup_a8c3922cfb7e8be63643ffb4dde3aa2f)
#         ;
#
#
#
#
#             var poly_line_bf521a877280a17f7d43673061e5f75e = L.polyline(
#                 [[35.681236, 139.767125], [35.6597, 139.75195], [35.658581, 139.745433]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;olive&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;olive&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 10}
#             ).addTo(map_39e3c8a1d0e59601a84254736a69ae08);
#
#
#             var marker_a834a906a14dccdf0e3eb8415c944161 = L.marker(
#                 [35.67, 139.74],
#                 {}
#             ).addTo(map_39e3c8a1d0e59601a84254736a69ae08);
#
#
#         var custom_icon_494aa5ccc6c60491ff124837d98a7033 = L.icon({&quot;iconSize&quot;: [10, 10], &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;});
#         marker_a834a906a14dccdf0e3eb8415c944161.setIcon(custom_icon_494aa5ccc6c60491ff124837d98a7033);
#
#
#             marker_a834a906a14dccdf0e3eb8415c944161.bindTooltip(
#                 `&lt;div&gt;
#                      mouse over
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
EARTH_RADIUS = 6378137

A = np.deg2rad(polyline.loc[0,:].tolist())
B = np.deg2rad(polyline.loc[1,:].tolist())
P = np.deg2rad(sample_dot)
print(A, B, P)
p = compute_arc_length(A[0], B[0], A[1], B[1])
a = compute_arc_length(B[0], P[0], B[1], P[1])
b = compute_arc_length(P[0], A[0], P[1], A[1])

alpha = np.arccos((np.cos(a) - np.cos(b) * np.cos(p)) / (np.sin(b) * np.sin(p)))
beta = np.arccos((np.cos(b) - np.cos(a) * np.cos(p)) / (np.sin(a) * np.sin(p)))
print(p, a, b, alpha, beta)

d = np.arcsin(np.sin(a) * np.sin(beta))
EARTH_RADIUS * d
# Out:
# [0.62275505 2.43939652] [0.62237918 2.43913166] [0.62255894 2.4389231 ]
# 0.00043310096690169067 0.0002470416957974734 0.00043168836059987586 0.5793955987789471 1.275618708705334
# 1507.5190008785598

# %%
d = np.arcsin(np.sin(b) * np.sin(alpha))
EARTH_RADIUS * d
# Out:
# 1507.519001484303

# %%
d
# Out:
# 0.00023635726254928407
